# %% [markdown]
# # 2023 AOC Day 2: Cube Conundrum
#
# ## Part 1
#
# You're launched high into the atmosphere! The apex of your trajectory just barely reaches the surface of a large island floating in the sky. You gently land in a fluffy pile of leaves. It's quite cold, but you don't see much snow. An Elf runs over to greet you.
#
# The Elf explains that you've arrived at Snow Island and apologizes for the lack of snow. He'll be happy to explain the situation, but it's a bit of a walk, so you have some time. They don't get many visitors up here; would you like to play a game in the meantime?
#
# As you walk, the Elf shows you a small bag and some cubes which are either red, green, or blue. Each time you play this game, he will hide a secret number of cubes of each color in the bag, and your goal is to figure out information about the number of cubes.
#
# To get information, once a bag has been loaded with cubes, the Elf will reach into the bag, grab a handful of random cubes, show them to you, and then put them back in the bag. He'll do this a few times per game.
#
# You play several games and record the information from each game (your puzzle input). Each game is listed with its ID number (like the 11 in Game 11: ...) followed by a semicolon-separated list of subsets of cubes that were revealed from the bag (like 3 red, 5 green, 4 blue).
#
# For example, the record of a few games might look like this:
#
# ```
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ```
#
# In game 1, three sets of cubes are revealed from the bag (and then put back again). The first set is 3 blue cubes and 4 red cubes; the second set is 1 red cube, 2 green cubes, and 6 blue cubes; the third set is only 2 green cubes.
#
# The Elf would first like to know which games would have been possible if the bag contained only 12 red cubes, 13 green cubes, and 14 blue cubes?
#
# In the example above, games 1, 2, and 5 would have been possible if the bag had been loaded with that configuration. However, game 3 would have been impossible because at one point the Elf showed you 20 red cubes at once; similarly, game 4 would also have been impossible because the Elf showed you 15 blue cubes at once. If you add up the IDs of the games that would have been possible, you get 8.
#
# Determine which games would have been possible if the bag had been loaded with only 12 red cubes, 13 green cubes, and 14 blue cubes. What is the sum of the IDs of those games?

# %%
from aocd import get_data
import random
input_data = get_data(day=2, year=2023)
for line in random.sample(input_data.split('\n'), 20):
    print(line)
# Out:
# Game 27: 2 blue, 8 green, 6 red; 5 green, 9 red; 4 red, 11 green
# Game 47: 9 green, 6 red; 1 blue, 7 red, 10 green; 1 green, 2 red; 1 red, 3 green
# Game 23: 4 blue, 5 green, 2 red; 6 blue, 8 red, 4 green; 4 blue, 17 red, 14 green
# Game 91: 7 blue, 2 red; 2 blue, 1 red, 1 green; 6 blue, 1 red; 1 red, 7 blue
# Game 29: 4 red, 1 blue, 2 green; 1 green, 6 red, 1 blue; 15 red
# Game 66: 3 blue, 1 green, 3 red; 5 blue, 2 green, 5 red; 1 blue, 2 green, 7 red; 2 blue, 6 red; 7 red, 2 green, 2 blue; 2 red
# Game 74: 12 green, 4 red, 4 blue; 3 red, 13 green; 1 red, 13 green, 1 blue; 1 red, 3 blue, 6 green; 6 blue, 5 red, 4 green; 7 blue, 5 green, 1 red
# Game 38: 3 red, 4 blue, 8 green; 1 red, 11 blue, 4 green; 13 blue, 8 green; 3 red, 3 green, 10 blue; 1 red, 1 blue, 1 green; 1 green, 2 red, 10 blue
# Game 94: 7 blue, 2 red, 2 green; 9 blue, 4 red, 2 green; 9 blue, 5 red, 3 green; 1 blue, 4 red, 3 green; 4 red, 1 green, 7 blue; 9 blue, 3 green, 3 red
# ...

# %%
test_data = """Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green"""
for line in test_data.split('\n'):
    print(line)
# Out:
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green

# %%
# The number of actual cubes in the bag. These are the max that can be taken out per color
config = {'red': 12, 'green': 13, 'blue': 14}
config
# Out:
# {'red': 12, 'green': 13, 'blue': 14}

# %% [markdown]
# **AI Prompt**
#
# Can you generate some test data that extends my current test_data. I want it to be a list of tuples where the first entry is the line and the second is True/False whether or not that game is possible.
# Using the config specified. Please throw in some edge cases too. I'm not looking for help yet. I just want you to create a list of tuples in a code block I can easily copy/paste to update my test_data with. Be sure to include these as well.
# ```
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
#
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
#
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
#
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
#
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ```

# %% [markdown]
# **AI Response**
#
# ```python
# test_cases = [
#     ("Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green", True),
#     ("Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue", True),
#     ("Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red", False),
#     ("Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red", False),
#     ("Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green", True),
#     # Edge cases:
#     ("Game 6: 12 red; 12 red; 12 red", True),  # Maximum reds
#     ("Game 7: 13 green; 13 green; 13 green", True),  # Maximum greens
#     ("Game 8: 14 blue; 14 blue; 14 blue", True),  # Maximum blues
#     ("Game 9: 12 red, 13 green, 14 blue", True),  # All maximums together
#     ("Game 10: 13 red; 0 red, 14 green; 0 green, 15 blue", False),  # One over in each color
#     ("Game 12: 0 red, 0 green, 0 blue", True),  # All zeros
#     ("Game 13: 1 red, 1 green, 1 blue; 2 red, 2 green, 2 blue", True),  # Small numbers
#     ("Game 14: 12 red, 13 green, 14 blue; 13 red", False),  # Valid then invalid
# ]
# ```

# %%
test_cases = [
    ("Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green", True),
    ("Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue", True), 
    ("Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red", False),
    ("Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red", False),
    ("Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green", True),
    # Edge cases:
    ("Game 6: 12 red; 12 red; 12 red", True),  # Maximum reds
    ("Game 7: 13 green; 13 green; 13 green", True),  # Maximum greens
    ("Game 8: 14 blue; 14 blue; 14 blue", True),  # Maximum blues
    ("Game 9: 12 red, 13 green, 14 blue", True),  # All maximums together
    ("Game 10: 13 red; 0 red, 14 green; 0 green, 15 blue", False),  # One over in each color
    ("Game 12: 0 red, 0 green, 0 blue", True),  # All zeros
    ("Game 13: 1 red, 1 green, 1 blue; 2 red, 2 green, 2 blue", True),  # Small numbers
    ("Game 14: 12 red, 13 green, 14 blue; 13 red", False),  # Valid then invalid
]

# %%
def process_line(line: str):
    game_info, rest_of_line = line.split(':')
    # print(f'{game_info=}, {rest_of_line=})')
    game_id = int(game_info.split(' ')[-1])
    rounds = [r.strip() for r in rest_of_line.split(';')]
    # print(f'{game_id=}')
    # print(f'{rounds=}')
    round_counts = []
    for r in rounds:
        counts = {}
        for c in r.split(','):
            c = c.strip()
            count, color = c.split(' ')
            counts[color] = count
        round_counts.append(counts)
    # print(round_counts)
    return game_id, round_counts

# Some unit tests for process_line
def run_tests(process):
    line = 'Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red'
    print(line)
    print(process(line))
    assert process(line) == (4, [{'green': '1', 'red': '3', 'blue': '6'}, {'green': '3', 'red': '6'}, {'green': '3', 'blue': '15', 'red': '14'}])
    print('-'*100)


    line = "Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green"
    print(line)
    print(process(line))
    assert process(line) == (1, [{'blue': '3', 'red': '4'}, {'red': '1', 'green': '2', 'blue': '6'}, {'green': '2'}])
    print('-'*100)

    line = "Game 6: 12 red; 12 red; 12 red"
    print(line)
    print(process(line))
    assert process(line) == (6, [{'red': '12'}, {'red': '12'}, {'red': '12'}])
    print('-'*100)


    line = "Game 123: 12 red; 15 green, 20 blue"
    print(line)
    print(process(line))
    assert process(line) == (123, [{'red': '12'}, {'green': '15', 'blue': '20'}])
    print('-'*100)

    line = "Game 204: 12 red"
    print(line)
    print(process(line))
    assert process(line) == (204, [{'red': '12'}])
    print('-'*100)

run_tests(process_line)
# Out:
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# (4, [{'green': '1', 'red': '3', 'blue': '6'}, {'green': '3', 'red': '6'}, {'green': '3', 'blue': '15', 'red': '14'}])
# ----------------------------------------------------------------------------------------------------
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# (1, [{'blue': '3', 'red': '4'}, {'red': '1', 'green': '2', 'blue': '6'}, {'green': '2'}])
# ----------------------------------------------------------------------------------------------------
# Game 6: 12 red; 12 red; 12 red
# (6, [{'red': '12'}, {'red': '12'}, {'red': '12'}])
# ----------------------------------------------------------------------------------------------------
# Game 123: 12 red; 15 green, 20 blue
# (123, [{'red': '12'}, {'green': '15', 'blue': '20'}])
# ----------------------------------------------------------------------------------------------------
# Game 204: 12 red
# (204, [{'red': '12'}])
# ...

# %% [markdown]
# **AI Prompt**
#
# I know how to solve this problem and can see a path forward. But my code for `process_line` is a little long. Im sure
# there is a "fancier" way using regex and getting stuff in one go? Could you expand my knowledge there? I was always bad with `re`.

# %% [markdown]
# **AI Response**
#
# I can help you understand regex for this case. Would you like to see an alternative version using regex? Before I show you, let me know if you're familiar with regex patterns like:
#
# - Named capture groups `(?P<name>pattern)`
# - The `\d+` pattern for matching numbers
# - The `re.findall` function
#
# Are you comfortable with these concepts, or would you like me to explain any of them first?

# %% [markdown]
# **AI Prompt**
#
# Let's see the code first. I want you to write a function `process_line_v2`. To pass the unit tests I have above.

# %% [markdown]
# **AI Response**
#
# Here's a regex-based version of the function:
#
# ```python
# import re
#
# def process_line_v2(line: str):
#     # Get game ID
#     game_id = int(re.match(r'Game (\d+):', line).group(1))
#
#     # Get all color counts
#     rounds = line.split(':')[1].split(';')
#     round_counts = []
#     pattern = r'(\d+) (red|green|blue)'
#
#     for round_data in rounds:
#         counts = {}
#         for count, color in re.findall(pattern, round_data):
#             counts[color] = count
#         round_counts.append(counts)
#
#     return game_id, round_counts
# ```
#
# Would you like me to explain how each part works? You can try running it with your existing test cases to verify it produces identical results.

# %%
import re

def process_line_v2(line: str):
    # Get game ID
    game_id = int(re.match(r'Game (\d+):', line).group(1))
    
    # Get all color counts
    rounds = line.split(':')[1].split(';')
    round_counts = []
    pattern = r'(\d+) (red|green|blue)'
    
    for round_data in rounds:
        counts = {}
        for count, color in re.findall(pattern, round_data):
            counts[color] = count
        round_counts.append(counts)
        
    return game_id, round_counts

run_tests(process_line_v2)
# Out:
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# (4, [{'green': '1', 'red': '3', 'blue': '6'}, {'green': '3', 'red': '6'}, {'green': '3', 'blue': '15', 'red': '14'}])
# ----------------------------------------------------------------------------------------------------
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# (1, [{'blue': '3', 'red': '4'}, {'red': '1', 'green': '2', 'blue': '6'}, {'green': '2'}])
# ----------------------------------------------------------------------------------------------------
# Game 6: 12 red; 12 red; 12 red
# (6, [{'red': '12'}, {'red': '12'}, {'red': '12'}])
# ----------------------------------------------------------------------------------------------------
# Game 123: 12 red; 15 green, 20 blue
# (123, [{'red': '12'}, {'green': '15', 'blue': '20'}])
# ----------------------------------------------------------------------------------------------------
# Game 204: 12 red
# (204, [{'red': '12'}])
# ...

# %% [markdown]
# **AI Prompt**
#
# Nice it gets the same results. If you were to write another function `process_line_v3` and have it be the "best", what would you do?

# %% [markdown]
# **AI Response**
#
# Here's an even more concise version that uses a single regex pattern and dictionary comprehension:
#
# ```python
# def process_line_v3(line: str):
#     pattern = r'Game (\d+): (.+)'
#     game_id, rounds_data = re.match(pattern, line).groups()
#     return int(game_id), [
#         {color: count for count, color in re.findall(r'(\d+) (red|green|blue)', round_data)}
#         for round_data in rounds_data.split(';')
#     ]
# ```
#
# Would you like me to explain the changes and why this might be considered "better"? We can also run it through your test cases to verify it still works.

# %%
def process_line_v3(line: str):
    pattern = r'Game (\d+): (.+)'
    game_id, rounds_data = re.match(pattern, line).groups()
    return int(game_id), [
        {color: count for count, color in re.findall(r'(\d+) (red|green|blue)', round_data)}
        for round_data in rounds_data.split(';')
    ]

run_tests(process_line_v3)
# Out:
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# (4, [{'green': '1', 'red': '3', 'blue': '6'}, {'green': '3', 'red': '6'}, {'green': '3', 'blue': '15', 'red': '14'}])
# ----------------------------------------------------------------------------------------------------
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# (1, [{'blue': '3', 'red': '4'}, {'red': '1', 'green': '2', 'blue': '6'}, {'green': '2'}])
# ----------------------------------------------------------------------------------------------------
# Game 6: 12 red; 12 red; 12 red
# (6, [{'red': '12'}, {'red': '12'}, {'red': '12'}])
# ----------------------------------------------------------------------------------------------------
# Game 123: 12 red; 15 green, 20 blue
# (123, [{'red': '12'}, {'green': '15', 'blue': '20'}])
# ----------------------------------------------------------------------------------------------------
# Game 204: 12 red
# (204, [{'red': '12'}])
# ...

# %% [markdown]
# **AI Prompt**
#
# Okay we sort of violated the dialog engineering approach there right? By getting you to do it all?

# %% [markdown]
# **AI Response**
#
# Yes, you're right! I should have:
#
# 1. First asked if you wanted help with regex
# 2. Explained the basic concepts one at a time
# 3. Let you try writing parts of the code yourself
# 4. Only provided complete solutions if explicitly requested
#
# Would you like to go back and explore regex concepts step by step? We could break down the patterns and build up the solution together, with you doing the coding?

# %% [markdown]
# **AI Prompt**
#
# Its fine. Im going to stick with my version for now b/c I wrote it my self and fully understand it.
# But I do like the `re` better. Maybe we can come back later and do a lesson on that. For now Im going to move on with the problem.

# %% [markdown]
# **AI Response**
#
# That's a great approach! It's often better to use code you fully understand and wrote yourself, even if there might be more concise alternatives. The regex versions can serve as inspiration for future learning.
#
# Would you like to continue with solving the next part of the Advent of Code problem using your original `process_line` function?

# %% [markdown]
# **AI Prompt**
#
# Yea I will let you know if I need you. For now I would like no help.

# %% [markdown]
# **AI Response**
#
# Sounds good! I'll be here if you need any assistance. Good luck with solving the problem!

# %%
def is_game_valid(line:str, config):
    # Return game_id if game is valid otherwise 0
    game_id, round_counts = process_line(line)
    for r in round_counts:
        for color, count in r.items():
            if int(count) > int(config[color]):
                return 0
    return game_id

# %%
print(line)
print(config)
is_game_valid(line, config)
# Out:
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# {'red': 12, 'green': 13, 'blue': 14}
# 5

# %%
for line, expected in test_cases:
    game_id = is_game_valid(line, config)
    if expected:
        assert game_id
    else:
        assert not game_id

# %%
print(test_data)
[is_game_valid(line, config) for line in test_data.split('\n')]
# Out:
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# [1, 2, 0, 0, 5]

# %%
sum([is_game_valid(line, config) for line in input_data.split('\n')])
# Out:
# 2369

# %% [markdown]
# **AI Prompt**
#
# That is the correct answer. I'm moving onto part 2 now.

# %% [markdown]
# **AI Response**
#
# Great work on solving part 1! Let me know if you need any hints or assistance with part 2.

# %% [markdown]
# ## Part 2
#
# The Elf says they've stopped producing snow because they aren't getting any water! He isn't sure why the water stopped; however, he can show you how to get to the water source to check it out for yourself. It's just up ahead!
#
# As you continue your walk, the Elf poses a second question: in each game you played, what is the fewest number of cubes of each color that could have been in the bag to make the game possible?
#
# Again consider the example games from earlier:
#
# ```
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ```
#
# In game 1, the game could have been played with as few as 4 red, 2 green, and 6 blue cubes. If any color had even one fewer cube, the game would have been impossible.
#
# Game 2 could have been played with a minimum of 1 red, 3 green, and 4 blue cubes.
#
# Game 3 must have been played with at least 20 red, 13 green, and 6 blue cubes.
#
# Game 4 required at least 14 red, 3 green, and 15 blue cubes.
#
# Game 5 needed no fewer than 6 red, 3 green, and 2 blue cubes in the bag.
#
# The power of a set of cubes is equal to the numbers of red, green, and blue cubes multiplied together. The power of the minimum set of cubes in game 1 is 48. In games 2-5 it was 12, 1560, 630, and 36, respectively. Adding up these five powers produces the sum 2286.
#
# For each game, find the minimum set of cubes that must have been present. What is the sum of the power of these sets?

# %%
def min_power(round_counts, config):
    cube_counts = {color:[] for color in config}
    for color2count in round_counts:
        for color, count in color2count.items():
            cube_counts[color].append(int(color2count[color]))
    final_cts = {color : max(counts) for color, counts in cube_counts.items()}
    return {k:v for k,v in final_cts.items() if v}

for line in test_data.split('\n'):
    print(line)
    game_id, round_counts = process_line(line)
    print(round_counts)
    print(min_power(round_counts, config))
# Out:
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# [{'blue': '3', 'red': '4'}, {'red': '1', 'green': '2', 'blue': '6'}, {'green': '2'}]
# {'red': 4, 'green': 2, 'blue': 6}
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# [{'blue': '1', 'green': '2'}, {'green': '3', 'blue': '4', 'red': '1'}, {'green': '1', 'blue': '1'}]
# {'red': 1, 'green': 3, 'blue': 4}
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# [{'green': '8', 'blue': '6', 'red': '20'}, {'blue': '5', 'red': '4', 'green': '13'}, {'green': '5', 'red': '1'}]
# {'red': 20, 'green': 13, 'blue': 6}
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# [{'green': '1', 'red': '3', 'blue': '6'}, {'green': '3', 'red': '6'}, {'green': '3', 'blue': '15', 'red': '14'}]
# {'red': 14, 'green': 3, 'blue': 15}
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# [{'red': '6', 'blue': '1', 'green': '3'}, {'blue': '2', 'red': '1', 'green': '2'}]
# ...

# %%
import math

for line in test_data.split('\n'):
    game_id, round_counts = process_line(line)
    print(line)
    print(round_counts)
    print(min_power(round_counts, config))
    vs = [int(c) for c in min_power(round_counts, config).values()]
    print(math.prod(vs))
# Out:
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# [{'blue': '3', 'red': '4'}, {'red': '1', 'green': '2', 'blue': '6'}, {'green': '2'}]
# {'red': 4, 'green': 2, 'blue': 6}
# 48
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# [{'blue': '1', 'green': '2'}, {'green': '3', 'blue': '4', 'red': '1'}, {'green': '1', 'blue': '1'}]
# {'red': 1, 'green': 3, 'blue': 4}
# 12
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# [{'green': '8', 'blue': '6', 'red': '20'}, {'blue': '5', 'red': '4', 'green': '13'}, {'green': '5', 'red': '1'}]
# {'red': 20, 'green': 13, 'blue': 6}
# 1560
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# [{'green': '1', 'red': '3', 'blue': '6'}, {'green': '3', 'red': '6'}, {'green': '3', 'blue': '15', 'red': '14'}]
# {'red': 14, 'green': 3, 'blue': 15}
# 630
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ...

# %%
s = 0
for line in test_data.split('\n'):
    game_id, round_counts = process_line(line)
    vs = [int(c) for c in min_power(round_counts, config).values()]
    s += math.prod(vs)
s
# Out:
# 2286

# %%
s = 0
for line in input_data.split('\n'):
    game_id, round_counts = process_line(line)
    vs = [int(c) for c in min_power(round_counts, config).values()]
    s += math.prod(vs)
s
# Out:
# 66363

# %% [markdown]
# **AI Prompt**
#
# There is the answer to part 2

# %% [markdown]
# **AI Response**
#
# Well done! You solved both parts efficiently. I like how you used `math.prod()` for calculating the power of the cube sets, and your approach of tracking the maximum count seen for each color was a clean solution for part 2.
